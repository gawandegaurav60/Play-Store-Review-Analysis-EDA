# %% [markdown]
# <a href="https://colab.research.google.com/github/gawandegaurav60/Play-Store-Review-Analysis-EDA/blob/main/Play_Store_App_Review_Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Play Store App Review Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name -** Gaurav Gawande

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project aimed to gather and analyze detailed information on apps in the Google Play Store in order to provide insights on app features and the current state of the Android app market.
#
# Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.
#
# The objective of this experiment is to deliver insights to understand customer demands better and thus help developers to popularize the product, hence the relationships among various attributes such as which application is free or paid, what are the user reviews, rating of the application are found.
# Various libraires like pandas, numpy, matplotlib and seaborn are used to perform such operations(data cleaning and visualization).
#
# At first the various libraries that are required were imported and both the datasets were loaded by mounting the google drive.
# Then the duplicate values and the null values from the both the datasets were taken care of.
# All the datatypes of the various columns of the dataframes are checked and changed as well if needed to help further analysis.
# Using the filtered and cleaned data 15 charts are created and some useful insights are obtained from them.
#
# Overall in this project Exploratory Data Analysis (EDA) approach is used to analyze the data using visual techniques and discover Trends, and Patterns with the help of statistical summaries and graphical representations.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/gawandegaurav60/Play-Store-Review-Analysis-EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **There are two datasets available. One containing the details of the apps like its name, category to which it belongs to, the rating it has, its size, etc. While the other one contains details regarding the reviews given to the apps by the users and the sentiments attached to the reviews.**
#
# **To explore and analyze the data to discover key factors responsible for app engagement and success.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights on user sentiment, app performance, and market trends can be drawn and used for strategic decision-making for app developers and stakeholders, aiming to optimize app performance, enhance user engagement, and maximize business impact.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
from ast import increment_lineno
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Reading csv file
play_store_path ="/content/drive/MyDrive/Colab Notebooks/AlmaBetter/Module 2/Capstone Project-EDA/Play Store Data.csv"
user_reviews_path ="/content/drive/MyDrive/Colab Notebooks/AlmaBetter/Module 2/Capstone Project-EDA/User Reviews.csv"
ps_df=pd.read_csv(play_store_path)
ur_df=pd.read_csv(user_reviews_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
ps_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
ur_df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(ps_df.shape)
print(ur_df.shape)
# Out:
# (10841, 13)
# (64295, 5)

# %%
# So we have 10841 rows and 13 columns in Play Store Data dataframe and
# 64295 rows and  5 columns in User Reviews dataframe

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
# for play store data
print(list(ps_df.columns))
ps_df.info()
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# ...

# %%
# for user reviews data
print(list(ur_df.columns))
ur_df.info()
# Out:
# ['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity', 'Sentiment_Subjectivity']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
# len(ps_df.duplicated())
duplicate_playstore = ps_df[ps_df.duplicated()]
duplicate_user_review = ur_df[ur_df.duplicated()]
print(len(duplicate_playstore))
print(len(duplicate_user_review))
# Out:
# 483
# 33616

# %%
# Here we have 483 duplicate values in Play Store Data and we need to get rid of those values
ps_df = ps_df.drop_duplicates('App', keep = 'first').reset_index(drop = True)
print(len(ps_df[ps_df.duplicated()]))
ps_df[ps_df.duplicated()]
# Out:
# 0
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
# Now we have zero duplicate values in the Play Store Dataset
# Also there's no need to drop duplicate values in User Review Dataset as there will be multiple reviews for a single app

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# for Play Store Dataset
print("Missing Values in each column of Play Store Data:"'\n', ps_df.isnull().sum())
# Out:
# Missing Values in each column of Play Store Data:
#  App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# for User Reviews Dataset
print("Missing Values in each column of User Reviews Data:"'\n', ur_df.isnull().sum())
# Out:
# Missing Values in each column of User Reviews Data:
#  App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Here we have a few missing values "Type", "Content Rating", "Current Ver", and "Android Ver"
# So simply drop them to avoid further analysis

missing_list = ["Type", "Content Rating", "Current Ver", "Android Ver"]
ps_df.dropna(subset=missing_list, inplace=True)
ps_df.reset_index(drop=True, inplace=True)
print("Missing Values in each column of Play Store Data:"'\n', ps_df.isnull().sum())
# Out:
# Missing Values in each column of Play Store Data:
#  App                  0
# Category             0
# Rating            1458
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %%
# Visualizing the missing values
import missingno as msno
# for the Play Store Dataset
msno.matrix(ps_df, figsize = (10, 5), fontsize = 10)
plt.setp(plt.title("Missing values from Play Store Data"), color = 'Black')
# Out:
# [None, None]

# %%
# for the User Review Dataset
msno.matrix(ur_df, figsize = (10, 5), fontsize = 10)
plt.setp(plt.title("Missing values from User Review Data"), color = 'Black')
# Out:
# [None, None]

# %%
# Now to deal with missing values from Rating column we'll find the mean, median and the mode of Rating column
# and replace the missing values with either one of them

# Calculating the mode and the median of the "Rating" column.
rating_mode = ps_df['Rating'].mode()[0]
rating_median = ps_df['Rating'].median()
rating_mean = ps_df['Rating'].mean()
print("Mode:",rating_mode, "Median:",rating_median, "Mean:", round(rating_mean, 1))
sns.displot(ps_df['Rating'], kde = True)
# Out:
# Mode: 4.3 Median: 4.3 Mean: 4.2

# %%
# Replacing the missing values with Median i.e. 4.3
ps_df['Rating'] = ps_df['Rating'].fillna(rating_median)
print("Missing Values in each column of Play Store Data:"'\n', ps_df.isnull().sum())
# Out:
# Missing Values in each column of Play Store Data:
#  App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# -There are 13 columns of properties with 10841 rows of data.
#
# -Column 'Reviews', 'Size', 'Installs' and 'Price' are in the type of 'object'
#
# -Values of column 'Size' are strings representing size in 'M' as Megabytes, 'k' as kilobytes and also 'Varies with devices'.
#
# -Values of column 'Installs' are strings representing install amount with symbols such as ',' and '+'.
#
# -Values of column 'Price' are strings representing price with symbol '$'.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
# for Play Store dataset
ps_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset Columns
# for user Review  dataset
ur_df.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe - Play Store dataset
ps_df.describe()
# Out:
#             Rating
# count  9648.000000
# mean      4.192465
# std       0.496552
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max       5.000000

# %%
# Dataset Describe - User Review dataset
ur_df.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# All the variables in the Play Store Dataset are:
#
# * App: The name of the app.
# * Category: The category to which the app belongs to.
# * Rating: The ratings (out of 5) given by the users to that particular app.
# * Reviews: The number of reviews given by the users to that particular app.
# * Size: The space required in the phone's memory to install that app.
# * Installs: The number of times that app has been installed by various users.
# * Type: Tells whether the app is free or paid.
# * Price: The price of the app if the app is paid, the price would be 0 if it is free.
# * Content Rating: The Age group for which the app is suitable for.
# * Genres: The genre(s) of the app.
# * Last Updated: The date on which the latest update for the app was released.
# * Current Ver: The current version of the app.
# * Android Ver: The android version that can support the app.
#
#
# ---
#
#
# All the variables in the User Reviews Dataset are:
#
# * App: The name of the app.
# * Translated_Review: The reviews given by the users translated to English.
# * Sentiment: The sentiment of the users towards that app. It can be Positive, Negative or Neutral.
# * Sentiment_Polarity: A measure of the sentiment. It has a range of [ -1, 1 ]. The more negative the number is, the more negative is the sentiment and the more positive it is, the more postive is the sentiment. If it is somewhere around 0, then it is a neutral sentiment.
# * Sentiment_Subjectivity: It defines how subjective are the reviews, or simply, by how much are the sentiments influenced by the personal opinions of the user. It has a range of [ 0, 1]. More closer it is to 0, the more objective (unbiased or free of personal opinions) are the sentiments, and the more closer it is to 1, the more subjective (biased or influenced by personal opinions) are the sentiments.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print("No of unique apps:", ps_df["App"].nunique())
print(ps_df["App"].unique())
# Out:
# No of unique apps: 9648
# ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps' ...
#  'Parkinson Exercices FR' 'The SCP Foundation DB fr nn5n'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']

# %%
print("No of unique categories of the apps:", ps_df["Category"].nunique())
print(ps_df["Category"].unique())
# Out:
# No of unique categories of the apps: 33
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION']

# %%
print("No of unique type of app:", ps_df["Type"].nunique())
print(ps_df["Type"].unique())
# Out:
# No of unique type of app: 2
# ['Free' 'Paid']

# %%
print("No of unique content ratings:", ps_df["Content Rating"].nunique())
print(ps_df["Content Rating"].unique())
# Out:
# No of unique content ratings: 6
# ['Everyone' 'Teen' 'Everyone 10+' 'Mature 17+' 'Adults only 18+' 'Unrated']

# %%
print("No of unique genres:", ps_df["Genres"].nunique())
print(ps_df["Genres"].unique())
# Out:
# No of unique genres: 118
# ['Art & Design' 'Art & Design;Pretend Play' 'Art & Design;Creativity'
#  'Art & Design;Action & Adventure' 'Auto & Vehicles' 'Beauty'
#  'Books & Reference' 'Business' 'Comics' 'Comics;Creativity'
#  'Communication' 'Dating' 'Education;Education' 'Education'
#  'Education;Creativity' 'Education;Music & Video'
#  'Education;Action & Adventure' 'Education;Pretend Play'
#  'Education;Brain Games' 'Entertainment' 'Entertainment;Music & Video'
#  'Entertainment;Brain Games' 'Entertainment;Creativity' 'Events' 'Finance'
#  'Food & Drink' 'Health & Fitness' 'House & Home' 'Libraries & Demo'
#  'Lifestyle' 'Lifestyle;Pretend Play' 'Adventure;Action & Adventure'
#  'Arcade' 'Casual' 'Card' 'Casual;Pretend Play' 'Action' 'Strategy'
#  'Puzzle' 'Sports' 'Music' 'Word' 'Racing' 'Casual;Creativity'
#  'Casual;Action & Adventure' 'Simulation' 'Adventure' 'Board' 'Trivia'
#  'Role Playing' 'Simulation;Education' 'Action;Action & Adventure'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# data types of the different columns/variables
ps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9648 non-null   object
#  1   Category        9648 non-null   object
#  2   Rating          9648 non-null   float64
#  3   Reviews         9648 non-null   object
#  4   Size            9648 non-null   object
#  5   Installs        9648 non-null   object
#  6   Type            9648 non-null   object
#  7   Price           9648 non-null   object
#  8   Content Rating  9648 non-null   object
#  9   Genres          9648 non-null   object
#  10  Last Updated    9648 non-null   object
#  11  Current Ver     9648 non-null   object
#  12  Android Ver     9648 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 980.0+ KB

# %%
# changing "Reviews" datatype

# it seems there are some values saying '__m' (more than a million reviews)
def convert_reviews(review):
    if 'M' in review:
        return int(float(review.replace('M', '')) * 1000000)
    else:
        return int(review)

ps_df['Reviews'] = ps_df['Reviews'].apply(convert_reviews)
ps_df['Reviews'] = ps_df['Reviews'].astype(int)

# %%
ps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9648 non-null   object
#  1   Category        9648 non-null   object
#  2   Rating          9648 non-null   float64
#  3   Reviews         9648 non-null   int64
#  4   Size            9648 non-null   object
#  5   Installs        9648 non-null   object
#  6   Type            9648 non-null   object
#  7   Price           9648 non-null   object
#  8   Content Rating  9648 non-null   object
#  9   Genres          9648 non-null   object
#  10  Last Updated    9648 non-null   object
#  11  Current Ver     9648 non-null   object
#  12  Android Ver     9648 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 980.0+ KB

# %%
# Changing the data type of "Size"
def convert_to_mb(value):
  if "k" in value:
    value = value.replace("k", "")
    output = round(float(value)/1024, 2)
  elif "M" in value:
    output = float(value.replace("M", ""))
  else:
    output = value
  return output
ps_df['Size'] = ps_df['Size'].apply(convert_to_mb)

ps_df['Size'].value_counts()
# Out:
# Size
# Varies with device    1226
# 12.0                   181
# 11.0                   181
# 13.0                   177
# 14.0                   176
#                       ...
# 0.1                      1
# 0.44                     1
# 0.18                     1
# 0.48                     1
# 0.66                     1
# Name: count, Length: 274, dtype: int64

# %%
# changing the data type of "Installs"
def string_to_int(value):
    if isinstance(value, float):  # Check if value is of type float
        return None
    if '+' in value:
        value = value.replace("+", "")
    if ',' in value:
        value = value.replace(",", "")
    if value.isdigit():
        return int(value)
    else:
        return None
ps_df['Installs'] = ps_df['Installs'].apply(string_to_int).astype('Int64')

print(ps_df['Installs'].value_counts())
# Out:
# Installs
# 1000000       1416
# 100000        1112
# 10000         1029
# 10000000       937
# 1000           886
# 100            709
# 5000000        607
# 500000         504
# 50000          468
# 5000           467
# 10             384
# 500            328
# 50             204
# 50000000       202
# 100000000      188
# 5               82
# 1               67
# 500000000       24
# 1000000000      20
# 0               14
# Name: count, dtype: Int64

# %%
# changing the "Price" column
def string_to_float(value):
    if value == 'Everyone':
        return np.nan
    elif '$' in value:
        value = value.replace("$", "")
    return float(value)

ps_df['Price'] = ps_df['Price'].apply(string_to_float)

ps_df['Price'].value_counts()
# Out:
# Price
# 0.00      8895
# 0.99       143
# 2.99       124
# 1.99        73
# 4.99        70
#           ...
# 18.99        1
# 389.99       1
# 19.90        1
# 1.75         1
# 1.04         1
# Name: count, Length: 92, dtype: int64

# %%
# as there multiple genres for some apps
# so converting the single string of genre value to list of multiple genres

ps_df['Genres'] = ps_df['Genres'].apply(lambda x: x.split(";"))
ps_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                          Genres      Last Updated         Current Ver  \
# 0                [Art & Design]   January 7, 2018               1.0.0
# ...

# %%
# converting the data type of "Last Updated" column as it should be date
from datetime import datetime
from dateutil.parser import parse

def parse_date(date_str):
    try:
        return parse(date_str)
    except ValueError:
        return None

ps_df['Last Updated'] = ps_df['Last Updated'].apply(parse_date)

ps_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                          Genres Last Updated         Current Ver   Android Ver
# 0                [Art & Design]   2018-01-07               1.0.0  4.0.3 and up
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The duplicate values from play store dataset are removed.
# Also the null/missing values from the play store dataset were removed and also replaced with respective median values if needed.
# The datatypes of the columns were changed for further analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1: Which Category has the most no of apps?

# %%
# Chart - 1 visualization code

ax = ps_df['Category'].value_counts().sort_values(ascending=True).plot.barh(width=0.8, color='purple', edgecolor='black', fontsize=7, figsize=(10, 6))

# Add count values on the bars
for i, v in enumerate(ps_df['Category'].value_counts().sort_values(ascending=True)):
    ax.text(v + 10, i, str(v), color='black', va='center', fontsize=7)

plt.title('Number of Apps in each Category', fontsize=12)
plt.ylabel('Category')
plt.xlabel('Number of Apps')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# There are different categories of the apps present in the database and we should know the no of apps in each category also which are the top categories in terms of no of apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Top 5 categories having the most number of apps are:
# 1. Family
# 2. Games
# 3. Tools
# 4. Medical
# 5. Business

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The identified categories offer opportunities for positive business impact, potential negative growth could arise from factors such as market saturation, intense competition, regulatory challenges, and user preferences shifting towards alternative solutions.

# %% [markdown]
# #### Chart - 2: Which Category has the most no of installs?

# %%
# Chart - 2 visualization code
ax = ps_df.groupby(['Category'])['Installs'].sum().sort_values().plot.barh(width=0.8, color='purple', edgecolor='black', fontsize=7, figsize=(10, 6))

# Add count values on the bars
for i, v in enumerate(ps_df.groupby(['Category'])['Installs'].sum().sort_values()):
    ax.text(v, i, str(v), color='black', va='center', fontsize=7, ha='left')

plt.title('Apps Installed for each Category')
plt.ylabel('Category')
plt.xlabel('Number of Installs')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In the earlier section, we checked for the number of apps in each category. Now, we will check the number of installs done for each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Top 5 categories with most number of apps installed are as follows:
# 1. Game
# 2. Communication
# 3. Tools
# 4. Productivity
# 5. Social
#
# We can definitely see difference between the 'Category vs. Number of Apps' (in the previous section) and 'Category vs. Number of Installs'.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights on top categories with the most installed apps offer significant business opportunities, businesses must carefully strategize and innovate to capitalize on these opportunities while addressing potential challenges to ensure sustainable growth and success.

# %% [markdown]
# #### Chart - 3: Which individual apps have the most no of installs?

# %%
# Chart - 3 visualization code
# sort the dataframe by 'Installs' column in descending order and select the top 20 rows
top_20_apps = ps_df.sort_values(by='Installs', ascending=False).head(20)

ax = top_20_apps.plot.barh(x='App', y='Installs', color='purple', edgecolor='black', figsize=(12, 8))

# Add count values on the bars
for i, v in enumerate(top_20_apps['Installs']):
    ax.text(v, i, str(v), color='black', va='center', fontsize=5, ha='left')

plt.title('Top 20 Most Installed Apps', fontsize=12)
plt.xlabel('Number of Installs', fontsize=10)
plt.ylabel('App', fontsize=10)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In order to check which apps are installed most no of times by the users regardless of the category in which they belong in.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top 20 apps have installs more than one billion and most of the apps in this top list are developed by Google,
# so Google is clearly leading in terms of no of installs across the different categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The dominance of Google-developed apps in the top install list can yield several positive outcomes, such as market leadership and revenue generation, it also raises concerns regarding market competition, innovation, and dependency risks. Google must navigate these challenges carefully to sustain its positive business impact and mitigate potential negative consequences.

# %% [markdown]
# #### Chart - 4: What is the percentage of free vs paid apps?

# %%
# Chart - 4 visualization code
# top 10 categories based on the number of installs
top_10_categories = ps_df.groupby('Category')['Installs'].sum().sort_values(ascending=False).head(10).index

# filter the DataFrame to include only the apps from these top 10 categories
top_10_apps_df = ps_df[ps_df['Category'].isin(top_10_categories)]

# group by "Category" and "Type" columns and count the number of paid and free apps in each category
category_type_counts = top_10_apps_df.groupby(['Category', 'Type']).size().unstack(fill_value=0)

# percentages of paid and free apps within each category
category_type_percentages = category_type_counts.div(category_type_counts.sum(axis=1), axis=0) * 100

fig, ax = plt.subplots(figsize=(12, 8))

# bars for free apps
bar_width = 0.35
index = range(len(top_10_categories))
bars_free = ax.bar(index, category_type_percentages['Free'], bar_width, label='Free', color='orange')

# bars for paid apps beside the free ones
bars_paid = ax.bar([i + bar_width for i in index], category_type_percentages['Paid'], bar_width, label='Paid', color='purple')

ax.set_xlabel('Categories')
ax.set_ylabel('Percentage of Apps')
ax.set_title('Percentage of Free and Paid Apps Across Top 10 Categories')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(top_10_categories, rotation=45, ha='right')
ax.legend()

# Adding percentage counts on top of each bar
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{:.1f}%'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(bars_free)
autolabel(bars_paid)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find out the percentage of the no of installs of free apps vs the paid apps across the categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As clearly seen from the plot the paid apps have a very small no of installs across the different categories. Not a single category have paid app installs that is more than 10%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it will help in creating a positive business if we know the exact idea of Free vs Paid apps distributions among the categories.

# %% [markdown]
# #### Chart - 5: Which are the top that categories generate revenue through app purchase?

# %%
# Chart - 5 visualization code
# the DataFrame to include only paid apps
paid_apps_df = ps_df[ps_df['Type'] == 'Paid']

# group by category and sum the prices for each category
price_sum_per_category = paid_apps_df.groupby('Category')['Price'].sum().sort_values(ascending=False)

# top 10 categories with the highest sum of prices for paid apps
top_10_paid_categories = price_sum_per_category.head(10)

plt.figure(figsize=(12, 8))
top_10_paid_categories.plot(kind='bar', color='purple')

plt.xlabel('Category')
plt.ylabel('Sum of Prices')
plt.title('Sum of Prices for Paid Apps in Top 10 Categories by Price')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find out the categories of apps which generates the most amount of money through the app purchases on the play store.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top categories which earn the most money through app purchases are:
# 1. Finance
# 2. Family
# 3. Lifestyle

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights may be much helpful with any impact or growth by focusing on the categories which have generated less money but have a lot of scope to grow more.

# %% [markdown]
# #### Chart - 6: Which apps are the most expensive in terms of play store app purchase?

# %%
# Chart - 6 visualization code
# Step 1: Sort the DataFrame by the 'Price' column in descending order
top_20_apps = ps_df.sort_values(by='Price', ascending=False).head(20)

# Step 2: Create a horizontal bar chart to visualize the prices of the top 20 apps
plt.figure(figsize=(20, 10))
plt.barh(top_20_apps['App'], top_20_apps['Price'], color='purple')

# Add labels and title
plt.xlabel('Price($)')
plt.ylabel('App')
plt.title('Top 20 Apps with the Highest Price')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-44-f88780d516e1>:15: UserWarning: Glyph 128142 (\N{GEM STONE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-44-f88780d516e1>:15: UserWarning: Glyph 25105 (\N{CJK UNIFIED IDEOGRAPH-6211}) missing from current font.
#   plt.tight_layout()
# <ipython-input-44-f88780d516e1>:15: UserWarning: Glyph 24456 (\N{CJK UNIFIED IDEOGRAPH-5F88}) missing from current font.
#   plt.tight_layout()
# <ipython-input-44-f88780d516e1>:15: UserWarning: Glyph 26377 (\N{CJK UNIFIED IDEOGRAPH-6709}) missing from current font.
#   plt.tight_layout()
# <ipython-input-44-f88780d516e1>:15: UserWarning: Glyph 37666 (\N{CJK UNIFIED IDEOGRAPH-9322}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128142 (\N{GEM STONE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find out which are the top 20 most high-priced apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the high-priced apps are some kind of funny showcase apps, meaning most of these apps are expesnive just for the sake of being expensive.
#
# The maximum price limit was set by Google Play in the year of 2015, that is why most of these apps are priced at around $400.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7: In which size group does most of the apps lie?

# %%
# Chart - 7 visualization code
def size_group(size):
  if type(size) == float:
    if size < 1:
      return 'Less than 1MB'
    elif size >= 1 and size < 10:
      return '1MB to 10MB'
    elif size >= 10 and size < 20:
      return '10MB to 20MB'
    elif size >= 20 and size < 30:
      return '20MB to 30MB'
    elif size >= 30 and size < 40:
      return '30MB to 40MB'
    elif size >= 40 and size < 50:
      return '40MB to 50MB'
    elif size >= 50 and size < 60:
      return '50MB to 60MB'
    elif size >= 60 and size < 70:
      return '60MB to 70MB'
    elif size >= 70 and size < 80:
      return '70MB to 80MB'
    elif size >= 80 and size < 90:
      return '80MB to 90MB'
    elif size >= 90 and size < 100:
      return '90MB to 100MB'
    elif size <= 100:
      return 'Greater than or equal to 100MB'
  else:
    return 'Varies with device'

lst_of_grps = ['Less than 1MB', '1MB to 10MB', '10MB to 20MB', '20MB to 30MB', '30MB to 40MB', '40MB to 50MB', '50MB to 60MB', '60MB to 70MB', '70MB to 80MB', '80MB to 90MB', '90MB to 100MB', 'Varies with device']


ps_df['Size Group'] = ps_df['Size'].apply(size_group)

size_group_df = ps_df.groupby(['Size Group'])['App'].count().to_frame().rename(columns = {'App': 'Number of Apps'}).reset_index()
sns.barplot(data = size_group_df, y = 'Size Group', x = 'Number of Apps', order = lst_of_grps, edgecolor ='black', linewidth = 1.5, palette ='Wistia')
plt.xticks(range(0, 3800, 200), rotation = 45)
plt.title('Number of Apps in Various Size Groups', fontsize = 12)
# Out:
# <ipython-input-45-8df9f97f6ecb>:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = size_group_df, y = 'Size Group', x = 'Number of Apps', order = lst_of_grps, edgecolor ='black', linewidth = 1.5, palette ='Wistia')
# Text(0.5, 1.0, 'Number of Apps in Various Size Groups')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check the number of apps lying in each of the groups categorised by size.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# So, most of the apps' size lies between 1MB to 10MB.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Developing the apps with an optimum size may more likely lead to success, and for larger sizes may lead to a negative growth.

# %% [markdown]
# #### Chart - 8: which content rating category has the most no of apps installs?

# %%
# Chart - 8 visualization code
cr_install_df = ps_df.groupby(['Content Rating'])['Installs'].sum().to_frame().sort_values(by = 'Installs', ascending = False).reset_index()
sns.set(rc={'figure.figsize':(10, 5)})
plt.ticklabel_format(useMathText = True)
sns.barplot(data = cr_install_df, x = 'Content Rating', y = 'Installs', width = 0.5, palette = 'brg', edgecolor='black', linewidth = 1.5)
plt.title('Number of Installs per Content Rating')
# Out:
# <ipython-input-46-e4f970df9f06>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = cr_install_df, x = 'Content Rating', y = 'Installs', width = 0.5, palette = 'brg', edgecolor='black', linewidth = 1.5)
# Text(0.5, 1.0, 'Number of Installs per Content Rating')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To have the knowledge about the different Content Rating and which are the top ones in terms of no of installs.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Majority of the installs were done from the 'Everyone' content rating, followed by the 'Teen' content rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, a positive impact can be created as now we know which content rating to target for.

# %% [markdown]
# #### Chart - 9: What are the different genres of apps available on play store and which are the most common ones?

# %%
# Chart - 9 visualization code
genre_list = []

for index, row in ps_df.iterrows():
  for element in row['Genres']:
    genre_list.append(element)

# Creating a dictionary to store all the genres and their count:
genre_count_dict = {}
for element in set(genre_list):
  genre_count_dict[element] = genre_list.count(element)

# Coverting that dictionary to a dataframe:
genre_count_df = pd.DataFrame(pd.Series(genre_count_dict)).reset_index()
genre_count_df.columns = ['Genres', 'Count']
genre_count_df = genre_count_df.sort_values(by = 'Count', ascending = False).reset_index(drop = True)

sns.set(rc={"figure.figsize":(18, 8)})
sns.barplot(data = genre_count_df, x = 'Genres', y = 'Count', palette = 'brg', linewidth = 0)
plt.xticks(rotation = 90)
plt.yticks(range(0, 900, 50))
plt.title('Genres and their Count', fontsize = 15)
# Out:
# <ipython-input-47-03eeeab5d017>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = genre_count_df, x = 'Genres', y = 'Count', palette = 'brg', linewidth = 0)
# Text(0.5, 1.0, 'Genres and their Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find out different genres on the play store and which are them most common ones.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It can be observed that the following are the top 3 most common genres in the apps:
#
# 1. Tools
# 2. Education
# 3. Entertainment

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights may help with positive business impact by focusing on the popular genres.

# %% [markdown]
# #### Chart - 10: Which are the apps with most no of positive sentiments?

# %%
# Chart - 10 visualization code
positive_ur_df = ur_df[ur_df['Sentiment'] == 'Positive']
positive_ur_df.groupby(['App'])['Sentiment'].count().nlargest(20).plot.barh(width = 0.3, color = 'purple', edgecolor='black', linewidth = 2, fontsize = 9,  figsize = (10, 6)).invert_yaxis()
plt.xlabel('Number of Positive Sentiments', fontsize = 10)
plt.title('Top 20 Most Positively Received Apps', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Top 20 Most Positively Received Apps')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get to know about the apps with the most number of positive sentiments, hence making them the most positively received apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Top 20 apps with the most no of positive reviews are found.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight may not be helpful in creating any growth or impact, but is essential in understanding the market for the apps.

# %% [markdown]
# #### Chart - 11: Which are the apps with most no of negative sentiments?

# %%
# Chart - 11 visualization code
negative_ur_df = ur_df[ur_df['Sentiment'] == 'Negative']
negative_ur_df.groupby(['App'])['Sentiment'].count().nlargest(20).plot.barh(width = 0.3, color = 'orange', edgecolor='black', linewidth = 2, fontsize = 9,  figsize = (10, 6)).invert_yaxis()
plt.xlabel('Number of Negative Sentiments', fontsize = 10)
plt.title('Top 20 Most Negatively Received Apps', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Top 20 Most Negatively Received Apps')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find out the apps with the number of negative sentiments, i.e. most negatively received apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top 5 apps with the most negative reviews are from 'Games' category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight may not be helpful in creating any growth or impact, but is essential in understanding the market for the apps.

# %% [markdown]
# #### Chart - 12: What are the most frequent words used in the positive reviews.

# %%
# Chart - 12 visualization code
from wordcloud import WordCloud, STOPWORDS

def sentiment_word_cloud(sentiment):
  all_the_words = ''

  for value in ur_df[ur_df['Sentiment'] == sentiment].Translated_Review.values:
    word_list = value.lower().split()
    all_the_words += ' '.join(word_list) + ' '

  stopwords = set(STOPWORDS)

  wordcloud = WordCloud(width = 1000, height = 1000, background_color = 'white', stopwords = stopwords).generate(all_the_words)
  plt.figure(figsize = (6, 6))
  plt.axis('off')
  plt.imshow(wordcloud)
sentiment_word_cloud('Positive')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To look for some of the most frequent words in the positive reviews.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# So, the most frequent words in the positive reviews can be seen in the above wordcloud. Some of the most frequent words are: 'great', 'good' and 'love'. Most of these words describe a positive feeling, so we can understand why these words are some of the most frequent in the positive reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these can contribute to a positive business impact. As most of these words can be later used for sentiment analysis on the unreviewed apps, to check whether they are positively received or not.

# %% [markdown]
# #### Chart - 13: What are the most frequent words used in the negative reviews?

# %%
# Chart - 13 visualization code
sentiment_word_cloud('Negative')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check the most frequent words in the negative reviews.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# So, the most frequent words in the negative reviews can be seen in the above wordcloud. Some of the most frequent words are: 'game', 'even', 'make' and 'time'. Unlike the wordcloud for the positive reviews, it is not as straight-forward to understand why some words are more frequent in the negative reviews. Although, we can see words like 'bad', 'hate', 'worst', 'problem', etc, which are associated with negative sentiments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these can contribute to a positive business impact. As some of these words can be carefuly selected and later used for sentiment analysis on the unreviewed apps, to check whether they are negatively received.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
ps1_df=ps_df[["Rating","Reviews","Installs","Price"]]
print(ps1_df.corr())

fig, axes = plt.subplots(figsize=(8, 8))
plt.title("co-relations of variables using a heatmap", fontsize=16)
sns.heatmap(ps1_df.corr(), ax=axes, annot=True, linewidths=0.1, fmt='.2f', square=True)
plt.show()
# Out:
#             Rating   Reviews  Installs     Price
# Rating    1.000000  0.050215  0.034310 -0.018673
# Reviews   0.050215  1.000000  0.625158 -0.007604
# Installs  0.034310  0.625158  1.000000 -0.009413
# Price    -0.018673 -0.007604 -0.009413  1.000000

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find out how the numerical variables are correlated with each other, hence a correlation heatmap is used.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is quite strong positive correlation between the 'Installs' and the 'Reviews'. So, the more the app installs by the users, the more reviews it will get. It can also imply that the app with more 'Reviews' tend to get more installs by the users.
#
# The 'Rating' is slightly postively correlated with the 'Installs'. This means that the higher rated apps tends to get installed more.
#
# The 'Rating' is slightly 'negatively correlated' with 'Price'. This means that the apps with higher price tends to get lower ratings.
#
# The 'Installs' is also slightly 'negatively correlated' with 'Price'. The apps with higher price don't get installed more often.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
pp = sns.pairplot(ps1_df)
pp.fig.suptitle("Distribution and relation of data ", y=1.00,fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plot is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters. It also helps to form some simple classification models by drawing some simple lines or make linear separation in our data-set.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The no of reviews are somewhat constant till the rating increases to 4 but after that no of reviews increases significantly.
#
# Most no of reviews are given to the apps that are free.
#
# App ratings are more for apps with less no of installs compared to apps with more install count.
#
# Almost most of the rating and reviews are given to free apps and as the price for apps increases there is significant drop in ratings as well as reviews.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# * Target popular app categories: The developers should target the 'Game', 'Tools', and 'Communication' categories as they have a high user base.
#
# * Focus on free apps: Since the market for free apps is vast, developers can benefit from creating free apps to attract a larger user base.
#
# * Develop paid apps in selected categories: The developers should focus on the 'Finance', 'Lifestyle', or 'Events' categories for paid apps, as these categories have the most number of paid apps and users may be willing to pay for well-designed apps in these categories.
#
# * Develop apps suitable for everyone: The developers should ensure that their apps are suitable for all age groups.
#
# * Regularly update apps: Regularly updating apps can improve user experience and increase positive reviews, leading to higher user engagement and satisfaction.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *   Top 5 categories having the most number of apps are:
#  1. Family
#  2. Games
#  3. Tools
#  4. Medical
#  5. Business
#
# *   Top 5 categories with most number of apps installed are as follows:
#  1. Game
#  2. Communication
#  3. Tools
#  4. Productivity
#  5. Social
#
# *   The top 20 apps have installs more than a billion and most of the apps in this top list are developed by Google, so Google is clearly leading in terms of no of installs across the different categories.
#
# *   The paid apps have a very small no of installs across the different categories and not a single category have paid app installs more than 10%.
#
# *  The top categories which earn the most amount money through app purchases are:
#  1. Finance
#  2. Family
#  3. Lifestyle
#
# *  Most of the high-priced apps are some kind of funny showcase apps, meaning most of these apps are expesnive just for the sake of being expensive.
#
#  The maximum price limit was set by Google Play in the year of 2015, that is why most of these apps are priced at around $400.
#
# *  The size of most of the apps lies between 1MB to 10MB.
#
#
# *  Majority of the installs were done from the 'Everyone' content rating, followed by the 'Teen' content rating.
#
# *  It can be observed that the following are the top 3 most common genres in the apps:
#  1. Tools
#  2. Education
#  3. Entertainment
#
# *  Top 20 apps with the most no of positive reviews are found.
#
# *  The top 5 apps with the most negative reviews are from 'Games' category.
#
# *  The most frequent words in the positive reviews taat can be seen in the wordcloud are: 'great', 'good' and 'love'. Most of these words describe a positive feeling, so we can understand why these words are some of the most frequent in the positive reviews.
#
# *  The most frequent words in the negative reviews that can be seen in the wordcloud are: 'game', 'even', 'make' and 'time'. Unlike the wordcloud for the positive reviews, it is not as straight-forward to understand why some words are more frequent in the negative reviews. Although, we can see words like 'bad', 'hate', 'worst', 'problem', etc, which are associated with negative sentiments.
#
# *  There is quite strong positive correlation between the Installs and          the Reviews. So, the more the app installs by the users, the more reviews it will
#   get. It can also imply that the app with more Reviews tend to get more installs by the users.
#
#   The Rating is slightly postively correlated with the Installs. This means that the higher rated apps tends to get installed more.
#
#   The Rating is slightly negatively correlated with Price. This means that the apps with higher price tends to get lower ratings.
#
#   The Installs is also slightly negatively correlated with Price. The apps with higher price don't get installed more often.
#
# *  The no of reviews are somewhat constant till the rating increases to 4 but
#    after that no of reviews increases significantly.
#
#    Most no of reviews are given to the apps that are free.
#
#    App ratings are more for apps with less no of installs compared to apps with more install count.
#
#    Almost most of the rating and reviews are given to free apps and as the price for apps increases there is significant drop in ratings as well as reviews.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
